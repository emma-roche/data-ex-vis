# %% [markdown]
# # Querying SQL databases
#
# Your task is to analyze game and player statistics from the NBA 2008-2009 season provided as a relational database of play-by-play data.
#
# You can use jupyter to execute the queries.
# You can compare your results with https://en.wikipedia.org/wiki/2008%E2%80%9309_NBA_season

# %% [markdown]
# ### Setup pymssql package

# %%
#! pip install --user pymssql

# %%
import pymssql
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv("/v/courses/2025-202425adatexplorcisvizualizci.public/basketball-mssql.env")

# Hide warnings for now
import warnings
warnings.filterwarnings('ignore')

# %%
# Connection info to the database
server=os.getenv("MSSQL_HOST")
port=os.getenv("MSSQL_PORT")
user=os.getenv("MSSQL_USER") 
password=os.getenv("MSSQL_PASSWORD")
database=os.getenv("MSSQL_DATABASE")

# %%
# This opens a connection to the MS SQL server
conn = pymssql.connect(server=server,
                      port=port,
                      user=user,
                      password=password,
                      database=database)

# This closes it 
# conn.close()

# %%
# We need a cursor that contains the state of our query(s)
cursor = conn.cursor()

# %%
# That is for the interactive schema browser
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b1902ae2-c06f-4c7a-b791-a59577073d17" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1e077677-34b0-4a1d-9d99-6cb5e80746fd":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"96ae7c606b6f406d8c3e81a0c4438d21","client_comm_id":"1c5306d71b004b5ba772d6470ed5ed43"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"1e077677-34b0-4a1d-9d99-6cb5e80746fd","roots":{"p1002":"b1902ae2-c06f-4c7a-b791-a59577073d17"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
tables = pd.read_sql('select * from INFORMATION_SCHEMA.tables', conn)
columns = pd.read_sql('select * from INFORMATION_SCHEMA.columns', conn)
cols = columns[['TABLE_NAME','COLUMN_NAME', 'DATA_TYPE']]

# %%
tables
# Out:
#    TABLE_CATALOG TABLE_SCHEMA        TABLE_NAME  TABLE_TYPE
# 0     Basketball          dbo      rebound_type  BASE TABLE
# 1     Basketball          dbo           rebound  BASE TABLE
# 2     Basketball          dbo             point  BASE TABLE
# 3     Basketball          dbo         shot_type  BASE TABLE
# 4     Basketball          dbo              shot  BASE TABLE
# 5     Basketball          dbo  freethrow_reason  BASE TABLE
# 6     Basketball          dbo         freethrow  BASE TABLE
# 7     Basketball          dbo      substitution  BASE TABLE
# 8     Basketball          dbo      timeout_type  BASE TABLE
# 9     Basketball          dbo           timeout  BASE TABLE
# 10    Basketball          dbo   turnover_reason  BASE TABLE
# 11    Basketball          dbo          turnover  BASE TABLE
# 12    Basketball          dbo    violation_type  BASE TABLE
# 13    Basketball          dbo         violation  BASE TABLE
# 14    Basketball          dbo             start  BASE TABLE
# 15    Basketball          dbo        conference  BASE TABLE
# 16    Basketball          dbo          division  BASE TABLE
# 17    Basketball          dbo              team  BASE TABLE
# 18    Basketball          dbo            person  BASE TABLE
# 19    Basketball          dbo          position  BASE TABLE
# 20    Basketball          dbo            player  BASE TABLE
# 21    Basketball          dbo              game  BASE TABLE
# 22    Basketball          dbo             event  BASE TABLE
# 23    Basketball          dbo   ejection_reason  BASE TABLE
# 24    Basketball          dbo          ejection  BASE TABLE
# 25    Basketball          dbo         foul_type  BASE TABLE
# 26    Basketball          dbo              foul  BASE TABLE
# 27    Basketball          dbo       sysdiagrams  BASE TABLE
# 28    Basketball          dbo          jumpball  BASE TABLE

# %%
columns
# Out:
#     TABLE_CATALOG TABLE_SCHEMA    TABLE_NAME     COLUMN_NAME  \
# 0      Basketball          dbo  rebound_type              id
# 1      Basketball          dbo  rebound_type     description
# 2      Basketball          dbo       rebound         game_id
# 3      Basketball          dbo       rebound            cntr
# 4      Basketball          dbo       rebound            type
# ..            ...          ...           ...             ...
# 109    Basketball          dbo      jumpball            cntr
# 110    Basketball          dbo      jumpball         team_id
# 111    Basketball          dbo      jumpball       player_id
# 112    Basketball          dbo      jumpball  home_player_id
# 113    Basketball          dbo      jumpball  away_player_id
#
#      ORDINAL_POSITION COLUMN_DEFAULT IS_NULLABLE DATA_TYPE  \
# 0                   1           None          NO   tinyint
# 1                   2           None          NO   varchar
# 2                   1           None          NO       int
# 3                   2           None          NO       int
# 4                   3           None          NO   tinyint
# ..                ...            ...         ...       ...
# 109                 2           None          NO       int
# 110                 3           None         YES      char
# 111                 4           None         YES       int
# 112                 5           None          NO       int
# 113                 6           None          NO       int
#
#      CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH  ...  \
# 0                         NaN                     NaN  ...
# 1                        50.0                    50.0  ...
# 2                         NaN                     NaN  ...
# 3                         NaN                     NaN  ...
# 4                         NaN                     NaN  ...
# ..                        ...                     ...  ...
# 109                       NaN                     NaN  ...
# 110                       3.0                     3.0  ...
# 111                       NaN                     NaN  ...
# 112                       NaN                     NaN  ...
# 113                       NaN                     NaN  ...
#
#      DATETIME_PRECISION  CHARACTER_SET_CATALOG  CHARACTER_SET_SCHEMA  \
# 0                   NaN                   None                  None
# 1                   NaN                   None                  None
# 2                   NaN                   None                  None
# 3                   NaN                   None                  None
# 4                   NaN                   None                  None
# ..                  ...                    ...                   ...
# 109                 NaN                   None                  None
# 110                 NaN                   None                  None
# 111                 NaN                   None                  None
# 112                 NaN                   None                  None
# 113                 NaN                   None                  None
#
#      CHARACTER_SET_NAME COLLATION_CATALOG COLLATION_SCHEMA   COLLATION_NAME  \
# 0                  None              None             None             None
# 1                cp1250              None             None  Hungarian_CI_AS
# 2                  None              None             None             None
# 3                  None              None             None             None
# 4                  None              None             None             None
# ..                  ...               ...              ...              ...
# 109                None              None             None             None
# 110              cp1250              None             None  Hungarian_CI_AS
# 111                None              None             None             None
# 112                None              None             None             None
# 113                None              None             None             None
#
#     DOMAIN_CATALOG DOMAIN_SCHEMA DOMAIN_NAME
# 0             None          None        None
# 1             None          None        None
# 2             None          None        None
# 3             None          None        None
# 4             None          None        None
# ..             ...           ...         ...
# 109           None          None        None
# 110           None          None        None
# 111           None          None        None
# 112           None          None        None
# 113           None          None        None
#
# [114 rows x 23 columns]

# %%
res = cursor.execute('select * from INFORMATION_SCHEMA.tables')
print(cursor.fetchall())
# Out:
# [('Basketball', 'dbo', 'rebound_type', 'BASE TABLE'), ('Basketball', 'dbo', 'rebound', 'BASE TABLE'), ('Basketball', 'dbo', 'point', 'BASE TABLE'), ('Basketball', 'dbo', 'shot_type', 'BASE TABLE'), ('Basketball', 'dbo', 'shot', 'BASE TABLE'), ('Basketball', 'dbo', 'freethrow_reason', 'BASE TABLE'), ('Basketball', 'dbo', 'freethrow', 'BASE TABLE'), ('Basketball', 'dbo', 'substitution', 'BASE TABLE'), ('Basketball', 'dbo', 'timeout_type', 'BASE TABLE'), ('Basketball', 'dbo', 'timeout', 'BASE TABLE'), ('Basketball', 'dbo', 'turnover_reason', 'BASE TABLE'), ('Basketball', 'dbo', 'turnover', 'BASE TABLE'), ('Basketball', 'dbo', 'violation_type', 'BASE TABLE'), ('Basketball', 'dbo', 'violation', 'BASE TABLE'), ('Basketball', 'dbo', 'start', 'BASE TABLE'), ('Basketball', 'dbo', 'conference', 'BASE TABLE'), ('Basketball', 'dbo', 'division', 'BASE TABLE'), ('Basketball', 'dbo', 'team', 'BASE TABLE'), ('Basketball', 'dbo', 'person', 'BASE TABLE'), ('Basketball', 'dbo', 'position', 'BASE TABLE'), ('Basketball', 'dbo', 'player', 'BASE TABLE'), ('Basketball', 'dbo', 'game', 'BASE TABLE'), ('Basketball', 'dbo', 'event', 'BASE TABLE'), ('Basketball', 'dbo', 'ejection_reason', 'BASE TABLE'), ('Basketball', 'dbo', 'ejection', 'BASE TABLE'), ('Basketball', 'dbo', 'foul_type', 'BASE TABLE'), ('Basketball', 'dbo', 'foul', 'BASE TABLE'), ('Basketball', 'dbo', 'sysdiagrams', 'BASE TABLE'), ('Basketball', 'dbo', 'jumpball', 'BASE TABLE')]

# %%
# A test query
res = cursor.execute('select * from player;')
print(cursor.fetchall())
# Out:
# [(1, 'ATL', '1', 'SF', 296), (2, 'ATL', '10', 'PG', 304), (3, 'ATL', '12', 'PG', 395), (4, 'ATL', '15', 'C', 7), (5, 'ATL', '2', 'SG', 212), (6, 'ATL', '22', 'SG', 363), (7, 'ATL', '24', 'SF', 290), (8, 'ATL', '27', 'C', 443), (9, 'ATL', '3', 'SG', 412), (10, 'ATL', '33', 'C', 341), (11, 'ATL', '4', 'PG', 3), (12, 'ATL', '44', 'C', 393), (13, 'ATL', '5', 'PF', 226), (14, 'ATL', '50', 'PF', 326), (15, 'ATL', '6', 'SG', 283), (16, 'BOS', '0', 'PF', 257), (17, 'BOS', '11', 'C', 157), (18, 'BOS', '12', 'SF', 166), (19, 'BOS', '13', 'SG', 152), (20, 'BOS', '20', 'SG', 348), (21, 'BOS', '26', 'C', 327), (22, 'BOS', '34', 'SF', 331), (23, 'BOS', '4', 'SF', 173), (24, 'BOS', '42', 'SG', 415), (25, 'BOS', '43', 'C', 233), (26, 'BOS', '44', 'C', 59), (27, 'BOS', '5', 'PF', 237), (28, 'BOS', '50', 'PG', 140), (29, 'BOS', '7', 'C', 310), (30, 'BOS', '8', 'PG', 399), (31, 'BOS', '9', 'PG', 339), (32, 'CHA', '1', 'PF', 18), (33, 'CHA', '1', 'SF', 70), (34, 'CHA', '10', 'SF', 430), (35, 'CHA', '12', 'SG', 386), (36, 'CHA', '13', 'SG', 293), (37, 'CHA', '14', 'PG', 94), (38, 'CHA', '15', 'C', 375), (39, 'CHA', '19', 'SG', 338), (40, 'CHA', '2', 'SG', 131), (41, 'CHA', '20', 'PG', 349), (42, 'CHA', '21', 'PF', 12), (43, 'CHA', '23', 'SG', 195), (44, 'CHA', '27', 'PF', 135), (45, 'CHA', '3', 'SF', 155), (46, 'CHA', '32', 'PF', 48), (47, 'CHA', '35', 'SF', 4), (48, 'CHA', '4', 'SF', 185), (49, 'CHA', '42', 'PF', 380), (50, 'CHA', '43', 'PF', 260), (51, 'CHA', '44', 'PG', 381), (52, 'CHA', '5', 'SF', 229), (53, 'CHA', '50', 'C', 144), (54, 'CHA', '6', 'C', 318), (55, 'CHA', '7', 'C', 120), (56, 'CHI', '1', 'PG', 119), (57, 'CHI', '11', 'PG', 259), (58, 'CHI', '12', 'SG', 242), (59, 'CHI', '13', 'C', 209), (60, 'CHI', '15', 'PF', 71), (61, 'CHI', '15', 'SF', 219), (62, 'CHI', '2', 'PF', 414), (63, 'CHI', '2', 'SF', 409), (64, 'CHI', '24', 'PF', 426), (65, 'CHI', '32', 'SF', 254), (66, 'CHI', '34', 'C', 2), (67, 'CHI', '35', 'SF', 116), (68, 'CHI', '5', 'PF', 23), (69, 'CHI', '5', 'PG', 33), (70, 'CHI', '52', 'C', 49), (71, 'CHI', '54', 'PF', 260), (72, 'CHI', '7', 'SG', 41), (73, 'CHI', '9', 'SF', 268), (74, 'CHI', '90', 'PF', 134), (75, 'CLE', '00', 'PF', 108), (76, 'CLE', '1', 'PG', 102), (77, 'CLE', '10', 'SF', 434), (78, 'CLE', '11', 'C', 444), (79, 'CLE', '13', 'SG', 114), (80, 'CLE', '17', 'PF', 16), (81, 'CLE', '2', 'PG', 311), (82, 'CLE', '21', 'C', 171), (83, 'CLE', '23', 'SF', 256), (84, 'CLE', '24', 'SG', 423), (85, 'CLE', '3', 'SF', 377), (86, 'CLE', '31', 'SF', 200), (87, 'CLE', '32', 'C', 213), (88, 'CLE', '4', 'PF', 42), (89, 'CLE', '55', 'C', 261), (90, 'CLE', '8', 'SG', 407), (91, 'DAL', '1', 'C', 375), (92, 'DAL', '11', 'SG', 170), (93, 'DAL', '13', 'SG', 293), (94, 'DAL', '2', 'PG', 193), (95, 'DAL', '21', 'SF', 35), (96, 'DAL', '25', 'C', 146), (97, 'DAL', '31', 'SG', 196), (98, 'DAL', '32', 'C', 51), (99, 'DAL', '33', 'PF', 183), (100, 'DAL', '4', 'SF', 391), (101, 'DAL', '40', 'SF', 124), (102, 'DAL', '41', 'PF', 128), (103, 'DAL', '42', 'SG', 207), (104, 'DAL', '5', 'SF', 223), (105, 'DAL', '7', 'C', 120), (106, 'DAL', '8', 'SG', 154), (107, 'DEN', '1', 'SG', 174), (108, 'DEN', '11', 'C', 77), (109, 'DEN', '12', 'PG', 87), (110, 'DEN', '13', 'SG', 394), (111, 'DEN', '15', 'SF', 68), (112, 'DEN', '25', 'PG', 28), (113, 'DEN', '27', 'C', 218), (114, 'DEN', '3', 'SG', 13), (115, 'DEN', '30', 'SG', 98), (116, 'DEN', '31', 'C', 320), (117, 'DEN', '32', 'PF', 351), (118, 'DEN', '35', 'C', 76), (119, 'DEN', '4', 'PF', 235), (120, 'DEN', '43', 'SF', 258), (121, 'DEN', '5', 'PF', 229), (122, 'DEN', '6', 'PG', 191), (123, 'DEN', '7', 'PG', 75), (124, 'DET', '1', 'PG', 13), (125, 'DET', '1', 'PG', 75), (126, 'DET', '12', 'PG', 435), (127, 'DET', '22', 'SF', 408), (128, 'DET', '24', 'PF', 37), (129, 'DET', '25', 'PF', 15), (130, 'DET', '28', 'SG', 38), (131, 'DET', '3', 'PG', 359), (132, 'DET', '30', 'C', 345), (133, 'DET', '32', 'SG', 352), (134, 'DET', '38', 'C', 247), (135, 'DET', '42', 'PF', 433), (136, 'DET', '5', 'SF', 432), (137, ...

# %% [markdown]
# ![schema diagramm](Basketball_DB_schema.png)

# %%
# Print a table with column names
cols[cols['TABLE_NAME']=='player'].set_index('TABLE_NAME')
# Out:
#             COLUMN_NAME DATA_TYPE
# TABLE_NAME
# player               id       int
# player          team_id      char
# player           number   varchar
# player      position_id   varchar
# player        person_id       int

# %%
# Print tables with holoviews, so it is easier to explore each table's structure
key_dimensions = ['TABLE_NAME']
value_dimensions = ['COLUMN_NAME', 'DATA_TYPE']
hv_data = hv.Table(cols, key_dimensions, value_dimensions)
#t1 = hv_data.to.table(['TABLE_NAME'], [] )
table_names = hv.Div(data="</br>".join(cols['TABLE_NAME'].unique()))
t2 = hv_data.to.table(['COLUMN_NAME', 'DATA_TYPE'])
tt = table_names + t2
#table_names

# %%
# This works in jupyterlab only for some reason. Go to the jupyter main page (file browser and click on the "Switch to JupyterLab" tab)
t2
# Out:
# :HoloMap   [TABLE_NAME]
#    :Table   [COLUMN_NAME,DATA_TYPE]

# %% [markdown]
# ## Excercise 1 - Simple queries
#
# a) List all teams playing in the league during the season
#
# b) List teams in alphabetic order but division by division
#
# c) Count the number of persons/players in the league

# %%
# Solving a)

pd.read_sql('SELECT * FROM team', conn)
# Out:
# 2023-03-29 14:15:30,707 [436] WARNING  py.warnings:109: [JupyterRequire] <ipython-input-15-9e6ff3abd3ab>:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('SELECT * FROM team', conn)
#      id division_id                    name
# 0   ATL          SE           Atlanta Hawks
# 1   BOS          AT          Boston Celtics
# 2   CHA          SE       Charlotte Bobcats
# 3   CHI          CE           Chicago Bulls
# 4   CLE          CE     Cleveland Cavaliers
# 5   DAL          SW        Dallas Mavericks
# 6   DEN          NW          Denver Nuggets
# 7   DET          CE         Detroit Pistons
# 8   GSW          PA   Golden State Warriors
# 9   HOU          SW         Houston Rockets
# 10  IND          CE          Indiana Pacers
# 11  LAC          PA    Los Angeles Clippers
# 12  LAL          PA      Los Angeles Lakers
# 13  MEM          SW       Memphis Grizzlies
# 14  MIA          SE              Miami Heat
# 15  MIL          CE         Milwaukee Bucks
# 16  MIN          NW  Minnesota Timberwolves
# 17  NJN          AT         New Jersey Nets
# 18  NOH          SW     New Orleans Hornets
# 19  NYK          AT         New York Knicks
# 20  OKC          NW   Oklahoma City Thunder
# 21  ORL          SE           Orlando Magic
# 22  PHI          AT      Philadelphia 76ers
# 23  PHX          PA            Phoenix Suns
# 24  POR          NW  Portland Trail Blazers
# 25  SAC          PA        Sacramento Kings
# 26  SAS          SW       San Antonio Spurs
# 27  TOR          AT         Toronto Raptors
# 28  UTA          NW               Utah Jazz
# 29  WAS          SE      Washington Wizards

# %% [markdown]
# ## Excercise 2 - Simple joins
#
# a) List teams by division, including the division name
#
# b) List players by team including the uniform number

# %%
# queries
