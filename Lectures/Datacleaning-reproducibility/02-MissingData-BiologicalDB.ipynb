# %% [markdown]
# ## Inspect a non-complete data set with the missingno package
# https://github.com/ResidentMario/missingno

# %%
#!pip install missingno --user
#!pip install --user pyarrow # for feather filetype

# %%
# Important to import matplotlib first, so we get the right version
import matplotlib as m
import missingno as msno
import pandas as pd

# %%
# Create a wider view for the notebook
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# These are cleaned data !!!
data = pd.read_feather("data/Virus_data.fr")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82900 entries, 0 to 82899
# Data columns (total 37 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Submission Date                            82900 non-null  datetime64[ns]
#  1   Last Update                                28776 non-null  datetime64[ns]
#  2   Outbreak or sporadic case O/S              56752 non-null  object
#  3   Source of the sample                       79640 non-null  object
#  4   Specify source                             516 non-null    object
#  5   Specify animal                             92 non-null     object
#  6   Suspected country of infection             75908 non-null  object
#  7   Date of first disease                      42320 non-null  datetime64[ns]
#  8   Geo-coded location                         78260 non-null  object
#  9   Suspected mode of transmission             36608 non-null  object
#  10  Specify other mode of transmission         524 non-null    object
#  11  Food item                                  2780 non-null   object
#  12  Setting of the outbreak                    44772 non-null  category
#  13  Point source transmission Y/N              31332 non-null  object
#  14  Date of point source transmission          1104 non-null   datetime64[ns]
#  15  Nr of persons affected                     21236 non-null  object
#  16  Nr of persons at risk                      11620 non-null  object
#  17  Nr of cases deceased                       9044 non-null   object
#  18  Nr of cases hospitalized due to infection  10628 non-null  object
#  19  Nr of cases of ages 0 to 4                 3464 non-null   object
#  20  Nr of cases of ages 5 to 14                3380 non-null   object
#  21  Nr of cases of age 65 or older             6588 non-null   object
#  22  Nr of cases with vomiting                  5584 non-null   object
#  23  Nr of cases with diarrhea                  5856 non-null   object
#  24  Mixed infection Y/N                        39852 non-null  object
#  25  Specify other pathogen(s)                  920 non-null    object
#  26  Nr of samples tested                       20976 non-null  object
#  27  Nr of PCR negative samples                 24464 non-null  object
#  28  Included in II.4 P2 capsid surveillance    12032 non-null  object
#  29  fragment_begin                             25977 non-null  float64
#  30  Genus-Genogroup                            82900 non-null  category
#  31  ORF1_variant                               7704 non-null   object
#  32  ORF2_variant                               6221 non-null   object
#  33  Cluster                                    18079 non-null  object
#  34  ORF1_genogroup                             82900 non-null  category
#  35  ORF2_genotype                              82900 non-null  category
#  36  ORF2_genogroup                             82900 non-null  category
# dtypes: category(5), datetime64[ns](4), float64(1), object(27)
# memory usage: 20.6+ MB

# %%
data.head()
# Out:
#   Submission Date Last Update Outbreak or sporadic case O/S  \
# 0      1992-01-01         NaT                             O
# 1      1994-01-01         NaT                             O
# 2      1994-01-01         NaT                             O
# 3      1997-01-01         NaT                             O
# 4      1997-01-01         NaT                             O
#
#   Source of the sample Specify source Specify animal  \
# 0                Human           None           None
# 1                Human           None           None
# 2                Human           None           None
# 3                Human           None           None
# 4                Human           None           None
#
#   Suspected country of infection Date of first disease  \
# 0                 UNITED KINGDOM            1992-01-01
# 1                 UNITED KINGDOM            1994-01-01
# 2                 UNITED KINGDOM            1994-01-01
# 3                        GERMANY            1997-01-01
# 4                        GERMANY            1997-01-01
#
#                              Geo-coded location  \
# 0  55.3780517578125,-3.4359729290008545,Country
# 1  55.3780517578125,-3.4359729290008545,Country
# 2  55.3780517578125,-3.4359729290008545,Country
# 3  51.16569137573242,10.451525688171387,Country
# 4  51.16569137573242,10.451525688171387,Country
#
#   Suspected mode of transmission  ... Nr of PCR negative samples  \
# 0                           None  ...                       None
# 1                           None  ...                       None
# 2                           None  ...                       None
# 3                           None  ...                       None
# 4                           None  ...                       None
#
#   Included in II.4 P2 capsid surveillance fragment_begin  \
# 0                                    None         4457.0
# 1                                    None         4479.0
# 2                                    None            NaN
# 3                                    None         4321.0
# 4                                    None         4336.0
#
#                 Genus-Genogroup ORF1_variant ORF2_variant  \
# 0  Caliciviridae Norovirus GIII         None         None
# 1   Caliciviridae Norovirus GII         None         None
# 2   Caliciviridae Norovirus GII         None         None
# 3   Caliciviridae Norovirus GII      US95_96         None
# 4   Caliciviridae Norovirus GII         None         None
#
#                     Cluster ORF1_genogroup ORF2_genotype ORF2_genogroup
# 0  Cluster 2: NoV II (II.3)        Unknown       Unknown        Unknown
# 1                      None            GII       Unknown        Unknown
# 2                      None        Unknown       Unknown        Unknown
# 3                      None            GII       Unknown        Unknown
# 4                      None            GII       Unknown        Unknown
#
# [5 rows x 37 columns]

# %%
# we don't need those, which are complete columns
# drop_cols = ['User', 'Institute', 'Database ID', 'Country', 'Submission Date',
#        'Outbreak Nr', 'Sample Date',
#        'fasta_id', 'Genus-Genogroup', 'ORF1',
#        'ORF2']
# data.drop(drop_cols, axis=1, inplace=True)

# %% [markdown]
# ### Figure that shows which elements are missing and which are present

# %%
#msno.matrix(data.sample(250))
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar chart that shows how many rows are filled of each column

# %%
msno.bar(data)
# Out:
# <Axes: >

# %% [markdown]
# ## Nullity correlation
# * -1,  if one variable appears the other definitely does not
# * 0, variables appearing or not appearing have no effect on one another
# * 1, if one variable appears the other definitely also does
#
# Variables that are always full or always empty have no meaningful correlation, and so are silently removed from the visualization—in this case for instance the datetime and injury number columns, which are completely filled, are not included.

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt

# from matplotlib.pyplot import grid

# fig, ax = plt.subplots(figsize=(20,12))
msno.heatmap(data)#.sample(100), ax=ax)
# ax.grid(color='r', linestyle='-', linewidth=2)
# ax.grid(True)#, markevery=0)
# ax.figure.figsize=(28,16)
# Out:
# <Axes: >

# %% [markdown]
# ### Dendrogram
# The dendrogram uses a hierarchical clustering algorithm (courtesy of scipy) to bin variables against one another by their nullity correlation (measured in terms of binary distance). At each step of the tree the variables are split up based on which combination minimizes the distance of the remaining clusters. The more monotone the set of variables, the closer their total distance is to zero, and the closer their average distance (the y-axis) is to zero.

# %%
msno.dendrogram(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Citation
#
# You may cite this package using the following format (via this paper):
#
#     Bilogur, (2018). Missingno: a missing data visualization suite. Journal of Open Source Software, 3(22), 547, https://doi.org/10.21105/joss.00547
